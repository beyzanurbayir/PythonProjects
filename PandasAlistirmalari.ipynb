# %% [markdown]
# <a href="https://colab.research.google.com/github/beyzanurbayir/PythonProjects/blob/master/PandasAlistirmalari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Alıştırma:
#
# Bir pandas serisi oluşturmak.

# %%
import numpy as np
import pandas as pd

# %%
isim=["ALİ","YAĞIZ","GÜL","ESMA"]
numara=[5,24,37,42]

# %%
pd.Series(data=isim,index=numara)
# Out:
# 5       ALİ
# 24    YAĞIZ
# 37      GÜL
# 42     ESMA
# dtype: object

# %%
pd.Series(data=numara,index=isim)
# Out:
# ALİ       5
# YAĞIZ    24
# GÜL      37
# ESMA     42
# dtype: int64

# %% [markdown]
# 2. Alıştırma:
#
# Dataframe tanımlamak.

# %%
# import numpy as np
# import pandas as pd

from numpy.random import randn

# %%
randn(5,5)
# Out:
# array([[-0.9232333 ,  1.21670919, -1.1369324 , -1.57514869,  0.75687949],
#        [-2.01837787,  1.04154796, -0.63820897, -0.29218717,  0.34831506],
#        [ 0.51942962, -1.37522205,  0.47438951,  1.25545677, -0.39565561],
#        [ 0.50248826, -0.58280449,  0.58818821,  0.91711956, -0.55541533],
#        [-0.62221677,  0.76836422, -0.2176126 , -1.44202684, -1.74134679]])

# %%
df= pd.DataFrame(data=randn(5,5),index="A B C D E".split(),columns="W X Y Z T".split())

# %%
df
# Out:
#           W         X         Y         Z         T
# A  1.231720  0.311874 -0.387619  1.307078 -0.256610
# B  0.664369 -1.387591  0.618624 -0.201276  0.283010
# C -3.001532  0.805293 -0.796487  0.110907  1.001893
# D -0.288913 -0.023941  0.238151 -0.006419  0.296880
# E -1.192457 -0.191267 -0.774809 -0.180681  0.159065

# %%
df["Q"]=df["W"]+df["X"]   # Yeni sütun ekledik

# %%
df
# Out:
#           W         X         Y         Z         T         Q
# A  1.231720  0.311874 -0.387619  1.307078 -0.256610  1.543594
# B  0.664369 -1.387591  0.618624 -0.201276  0.283010 -0.723222
# C -3.001532  0.805293 -0.796487  0.110907  1.001893 -2.196239
# D -0.288913 -0.023941  0.238151 -0.006419  0.296880 -0.312855
# E -1.192457 -0.191267 -0.774809 -0.180681  0.159065 -1.383724

# %%
df.drop("Q",axis=1)   # Q sütununu sildik ama kalıcı olarak değil
# Out:
#           W         X         Y         Z         T
# A  1.231720  0.311874 -0.387619  1.307078 -0.256610
# B  0.664369 -1.387591  0.618624 -0.201276  0.283010
# C -3.001532  0.805293 -0.796487  0.110907  1.001893
# D -0.288913 -0.023941  0.238151 -0.006419  0.296880
# E -1.192457 -0.191267 -0.774809 -0.180681  0.159065

# %%
df
# Out:
#           W         X         Y         Z         T         Q
# A  1.231720  0.311874 -0.387619  1.307078 -0.256610  1.543594
# B  0.664369 -1.387591  0.618624 -0.201276  0.283010 -0.723222
# C -3.001532  0.805293 -0.796487  0.110907  1.001893 -2.196239
# D -0.288913 -0.023941  0.238151 -0.006419  0.296880 -0.312855
# E -1.192457 -0.191267 -0.774809 -0.180681  0.159065 -1.383724

# %%
df.drop("Q",axis=1, inplace=True)  # Q sütununu kalıcı olarak sildik

# %%
df
# Out:
#           W         X         Y         Z         T
# A  1.231720  0.311874 -0.387619  1.307078 -0.256610
# B  0.664369 -1.387591  0.618624 -0.201276  0.283010
# C -3.001532  0.805293 -0.796487  0.110907  1.001893
# D -0.288913 -0.023941  0.238151 -0.006419  0.296880
# E -1.192457 -0.191267 -0.774809 -0.180681  0.159065

# %%
df>=0
# Out:
#        W      X      Y      Z      T
# A   True   True  False   True  False
# B   True  False   True  False   True
# C  False   True  False   True   True
# D  False  False   True  False   True
# E  False  False  False  False   True

# %%
df[df>=0]
# Out:
#           W         X         Y         Z         T
# A  1.231720  0.311874       NaN  1.307078       NaN
# B  0.664369       NaN  0.618624       NaN  0.283010
# C       NaN  0.805293       NaN  0.110907  1.001893
# D       NaN       NaN  0.238151       NaN  0.296880
# E       NaN       NaN       NaN       NaN  0.159065

# %% [markdown]
# 3. Alıştırma:
#
# NaN değerleri yerine o sütundaki değerlerin ortalamasını atamak

# %%
df=pd.DataFrame({'A':[1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(df.mean())
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  1.5  5.0  3
